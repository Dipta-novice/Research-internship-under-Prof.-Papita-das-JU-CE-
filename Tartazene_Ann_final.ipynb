# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data2=pd.read_excel("/content/drive/My Drive/Book1.xlsx")

# %%
data=pd.read_excel("/content/drive/My Drive/Book2n.xlsx")

# %%
data2
# Out:
#     Tar.(ppm)  Adose(g/L)  pH  Temperature  time
# 0          10        2.00   2         25.0     0
# 1          90        2.00  10         40.0   120
# 2          10        0.50   2         40.0     0
# 3          50        1.25   6         32.5    60
# 4          90        2.00   2         25.0   120
# 5          10        2.00  10         25.0   120
# 6          10        0.50  10         25.0     0
# 7          50        1.25  14         32.5    60
# 8          90        2.00  10         25.0     0
# 9          10        0.50  10         40.0   120
# 10         50        1.25   6         47.5    60
# 11         50        1.25   6         17.5    60
# 12         50        2.75   6         32.5    60
# 13         90        0.50  10         25.0   120
# 14         50        1.25   6         32.5    60
# 15        130        1.25   6         32.5    60
# 16         10        0.50   2         25.0   120
# 17         90        0.50   2         25.0     0
# ...

# %%
dd=data.drop(axis=0,index=[6,20,87,53,66])

# %%
ddtest=data.loc[[6,20,87,53,66]]

# %%
y_train=dd.iloc[:,-4]
x_train=dd.iloc[:,0:5]

# %%
y_test=ddtest.iloc[:,-4]
x_test=ddtest.iloc[:,0:5]

# %%
x_train.shape[1]
# Out:
# 5

# %%
pip install keras-tuner
# Out:
# ...
#      |████████████████████████████████| 98 kB 2.9 MB/s
# ...

# %%
from keras.models import Sequential
import kerastuner
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from kerastuner.tuners import RandomSearch
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.

# %%
from tensorflow.keras import layers

# %%
model = Sequential()
model.add(Dense(368, activation= 'relu', input_dim= x_train.shape[1]))
model.add(Dense(144, activation= 'relu'))
model.add(Dense(144, activation= 'relu'))
model.add(Dense(32, activation= 'relu'))
model.add(Dense(units=1, activation='linear'))
              
model.compile(optimizer = 'adam', loss = 'mean_absolute_error', metrics = ['mean_absolute_error'])

model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=20)

y_pred = model.predict(x_test)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 1s 72ms/step - loss: 4.7307 - mean_absolute_error: 4.7307 - val_loss: 5.4685 - val_mean_absolute_error: 5.4685
# Epoch 2/20
# 3/3 [==============================] - 0s 12ms/step - loss: 3.5178 - mean_absolute_error: 3.5178 - val_loss: 5.0022 - val_mean_absolute_error: 5.0022
# Epoch 3/20
# 3/3 [==============================] - 0s 12ms/step - loss: 2.9899 - mean_absolute_error: 2.9899 - val_loss: 4.6402 - val_mean_absolute_error: 4.6402
# Epoch 4/20
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7011 - mean_absolute_error: 2.7011 - val_loss: 4.0450 - val_mean_absolute_error: 4.0450
# Epoch 5/20
# 3/3 [==============================] - 0s 15ms/step - loss: 2.5594 - mean_absolute_error: 2.5594 - val_loss: 3.4338 - val_mean_absolute_error: 3.4338
# Epoch 6/20
# 3/3 [==============================] - 0s 13ms/step - loss: 2.4117 - mean_absolute_error: 2.4117 - val_loss: 3.0050 - val_mean_absolute_error: 3.0050
# ...

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_18 (Dense)            (None, 368)               2208
#
#  dense_19 (Dense)            (None, 144)               53136
#
#  dense_20 (Dense)            (None, 144)               20880
#
#  dense_21 (Dense)            (None, 32)                4640
#
#  dense_22 (Dense)            (None, 1)                 33
#
# ...
# Total params: 80,897
# Trainable params: 80,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
ypred=model.predict(x_test)

# %%
ypred
# Out:
# array([[100.27985 ],
#        [ 13.045533],
#        [119.572235],
#        [ 94.72499 ],
#        [ 97.49235 ]], dtype=float32)

# %%
y_test
# Out:
# 6     97.844586
# 20     5.213172
# 87    85.523586
# 53    98.418724
# 66    95.054276
# Name: %removal  , dtype: float64

# %%
x_test
# Out:
#     (ppm)  ad_dose(g/L)  ph_value  Temperature(⁰C)  time
# 6      20           1.0         6               30    30
# 20     90           1.0         6               30    15
# 87     30           1.0         6               40    30
# 53     30           1.0         4               30    45
# 66     30           1.0        10               30    15

# %%
ypred
# Out:
# array([[100.27985 ],
#        [ 13.045533],
#        [119.572235],
#        [ 94.72499 ],
#        [ 97.49235 ]], dtype=float32)

# %%
x2=data2.iloc[:,0:5]

# %%
x2
# Out:
#     Tar.(ppm)  Adose(g/L)  pH  Temperature  time
# 0          10        2.00   2         25.0     0
# 1          90        2.00  10         40.0   120
# 2          10        0.50   2         40.0     0
# 3          50        1.25   6         32.5    60
# 4          90        2.00   2         25.0   120
# 5          10        2.00  10         25.0   120
# 6          10        0.50  10         25.0     0
# 7          50        1.25  14         32.5    60
# 8          90        2.00  10         25.0     0
# 9          10        0.50  10         40.0   120
# 10         50        1.25   6         47.5    60
# 11         50        1.25   6         17.5    60
# 12         50        2.75   6         32.5    60
# 13         90        0.50  10         25.0   120
# 14         50        1.25   6         32.5    60
# 15        130        1.25   6         32.5    60
# 16         10        0.50   2         25.0   120
# 17         90        0.50   2         25.0     0
# ...

# %%
r=model.predict(x2)

# %%
r
# Out:
# array([[ 0.7537788 ],
#        [11.577742  ],
#        [ 1.1939484 ],
#        [ 5.041302  ],
#        [14.137435  ],
#        [-0.22101204],
#        [ 0.66283655],
#        [ 4.881248  ],
#        [25.378147  ],
#        [ 0.3589705 ],
#        [ 2.7385733 ],
#        [ 8.27961   ],
#        [ 4.7186265 ],
#        [14.258853  ],
#        [ 5.041302  ],
#        [35.25561   ],
#        [ 0.0965515 ],
#        [26.066772  ],
#        [ 5.041302  ],
#        [ 1.5750366 ],
#        [ 5.041302  ],
#        [ 0.91289383],
#        [24.152754  ],
#        [ 0.50388175],
#        [ 5.041302  ],
#        [ 5.041302  ],
#        [11.921277  ],
#        [23.676468  ]], dtype=float32)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-79a0c4e68a30> in <module>()
# ----> 1 x2.concat(r)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
yrsmpred
# Out:
# array([[nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan]], dtype=float32)

# %%
data2['%removal']=yrsmpred

# %%
data2
# Out:
#     Tartazene_conc  Adsorbent_dose(g/L)  pH   time  %removal
# 0               90                 2.00   2  120.0       NaN
# 1              130                 1.25   6   67.5       NaN
# 2               50                 1.25   6  -37.5       NaN
# 3               90                 0.50  10   15.0       NaN
# 4               90                 0.50   2   15.0       NaN
# 5               50                 2.75   6   67.5       NaN
# 6               90                 2.00  10  120.0       NaN
# 7               50                 1.25   6   67.5       NaN
# 8               10                 2.00   2  120.0       NaN
# 9               90                 0.50  10  120.0       NaN
# 10              50                 1.25   6  172.5       NaN
# 11              90                 2.00   2   15.0       NaN
# 12              50                 1.25   6   67.5       NaN
# 13              50                -0.25   6   67.5       NaN
# ...
